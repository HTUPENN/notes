# %% [markdown]
# # title
#
# <details>
# <summary>插入图片</summary>
#
# ![boxplot.png](./path/to/file/boxplot.png)
# </details>
#
# | 表头1 | 表头2 | 表头3 |
# |-------|-------|-------|
# | 内容A | 内容B | 内容C |
# | 内容D | 内容E | 内容F |

# %%
# FIXME: 或 # XXX:：

这些注释通常用于标记需要修复或改进的代码。IDE（如VSCode、PyCharm等）通常会为它们添加特殊的颜色或警告提示，以便开发者在后续检查时注意到。

# NOTE:

用于标记重要的说明或需要注意的地方，IDE也可能为它提供高亮显示，以提醒开发者这是一个关键的注释。

# HACK:

用于标记一些临时的解决方案或不太规范的代码段，表示开发者意识到该部分可能存在问题或不完美。IDE也可能为其加上不同颜色的高亮。

# REVIEW:

用于标记需要复审的代码部分，提示开发者或团队成员进行检查。IDE中也可能高亮这些注释，提醒需要进行代码审查。

# BUG:

标记已知的缺陷或bug。在一些IDE中，这类注释也可能被标亮或添加特别的符号。

# DEPRECATED:

标记过时或不推荐使用的代码，通常是提示开发者尽量避免使用此功能，或者该功能在未来版本中会被移除。
